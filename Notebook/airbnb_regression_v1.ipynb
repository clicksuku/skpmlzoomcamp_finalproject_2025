# %%
import pandas as pd
import json
import numpy as np
import seaborn as sn
import pickle

from matplotlib import pyplot as plt
from io import StringIO
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error, f1_score, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
df_listings_details = pd.read_csv('../data/listings_detailed.csv')
df_listings = pd.read_csv('../data/listings.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df_listings_details.head(2)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  40625  https://www.airbnb.com/rooms/40625  20250914152932   2025-09-14
# 1  51287  https://www.airbnb.com/rooms/51287  20250914152932   2025-09-14
#
#         source                                               name  \
# 0  city scrape                     Near Palace Schönbrunn, Apt. 1
# 1  city scrape  little studio- next to citycenter- wifi- nice ...
#
#                                          description  \
# 0  Welcome to my Apt. 1!<br /><br />This is a 2be...
# 1  small studio in new renovated old house and ve...
#
#                                neighborhood_overview  \
# 0  The neighbourhood offers plenty of restaurants...
# 1  The neighbourhood has a lot of very nice littl...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/11509144/d55c...   175131
# 1  https://a0.muscache.com/pictures/25163038/1c4e...   166283
#
#                                    host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/175131    Ingela  2010-07-20
# 1  https://www.airbnb.com/users/show/166283    Hannes  2010-07-14
#
#      host_location                                         host_about  \
# 0  Vienna, Austria  I´m originally from Sweden but have been livin...
# 1  Vienna, Austria  I am open minded and like travelling myself. I...
#
#   host_response_time host_response_rate host_acceptance_rate  \
# 0     within an hour               100%                  95%
# 1     within an hour               100%                 100%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0               NaN  https://a0.muscache.com/im/users/175131/profil...
# 1                 t  https://a0.muscache.com/im/users/166283/profil...
#
#                                     host_picture_url    host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/175131/profil...  Rudolfsheim-Fünfhaus
# 1  https://a0.muscache.com/im/users/166283/profil...          Leopoldstadt
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                 15.0                       18.0  ['email', 'phone']
# 1                  2.0                        3.0  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified    neighbourhood  \
# 0                    t                      t  Vienna, Austria
# 1                    t                      t  Vienna, Austria
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  longitude  \
# 0   Rudolfsheim-Fnfhaus                           NaN  48.18434   16.32701
# 1           Leopoldstadt                           NaN  48.21778   16.37847
#
#         property_type        room_type  accommodates  bathrooms  \
# 0  Entire rental unit  Entire home/apt             6        1.0
# 1  Entire rental unit  Entire home/apt             2        1.0
#
#   bathrooms_text  bedrooms  beds  \
# 0         1 bath       2.0   3.0
# 1         1 bath       0.0   2.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Smoke alarm", "Pack \u2019n play/Travel crib...  $140.00               1
# 1  ["Smoke alarm", "Stove", "Coffee maker", "Drye...   $71.00              30
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0             365                     1.0                    30.0
# 1             180                    30.0                    30.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                   365.0                   365.0                    16.3
# 1                   180.0                   180.0                    30.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                   365.0               NaN                t               18
# 1                   180.0               NaN                t                0
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               34               61               137            2025-09-14
# 1                0               27               207            2025-09-14
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                225                      8                       1
# 1                383                      3                       0
#
#    availability_eoy  number_of_reviews_ly  estimated_occupancy_l365d  \
# 0                69                    15                         48
# 1                46                     9                        180
#
#    estimated_revenue_l365d first_review last_review  review_scores_rating  \
# 0                   6720.0   2010-08-04  2025-08-20                  4.86
# 1                  12780.0   2011-01-27  2025-07-04                  4.67
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    4.91                       4.89                   4.89
# 1                    4.78                       4.51                   4.92
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.94                    4.61                 4.73
# 1                         4.95                    4.87                 4.59
#
#    license instant_bookable  calculated_host_listings_count  \
# 0      NaN                f                              14
# 1      NaN                f                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           13
# 1                                            2
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               1.22
# 1                                            0               2.15

# %%
listings_selected_columns = ['id', 'name_x', 'room_type_x', 'minimum_nights_y', 
   'availability_eoy', 'availability_365_x', 
    'estimated_occupancy_l365d', 'estimated_revenue_l365d',
    'number_of_reviews_y', 'number_of_reviews_l30d', 'reviews_per_month_y', 
    'review_scores_rating', 'review_scores_accuracy','review_scores_checkin', 'review_scores_cleanliness',
    'review_scores_communication', 'review_scores_location', 'review_scores_value', 
    'instant_bookable', 'calculated_host_listings_count_y', 'price_x']

# %%
listings_selected_columns = ['id', 'name', 'room_type', 'minimum_nights', 
   'availability_eoy', 'availability_365', 
    'estimated_occupancy_l365d', 'estimated_revenue_l365d',
    'number_of_reviews', 'number_of_reviews_l30d', 'reviews_per_month', 
    'review_scores_rating', 'review_scores_accuracy','review_scores_checkin', 'review_scores_cleanliness',
    'review_scores_communication', 'review_scores_location', 'review_scores_value', 
    'instant_bookable', 'calculated_host_listings_count', 'price']

# %%
df_merged_listings = pd.concat([df_listings, df_listings_details], axis=1)

# %%
df_regression_master = df_regression_master.loc[:, ~df_regression_master.columns.duplicated()]

# %%
listings_selected_columns = ['room_type', 'minimum_nights', 
   'availability_eoy', 'availability_365', 
    'estimated_occupancy_l365d', 'estimated_revenue_l365d',
    'number_of_reviews', 'number_of_reviews_l30d', 'reviews_per_month', 
    'review_scores_rating', 'review_scores_value', 
    'instant_bookable', 'calculated_host_listings_count', 'price']

# %%
df_regression_master = df_merged_listings[listings_selected_columns]

# %%
df_regression_master.head(1)
# Out:
#          room_type        room_type  minimum_nights  minimum_nights  \
# 0  Entire home/apt  Entire home/apt               1               1
#
#    availability_eoy  availability_365  availability_365  \
# 0                69               137               137
#
#    estimated_occupancy_l365d  estimated_revenue_l365d  number_of_reviews  \
# 0                         48                   6720.0                225
#
#    number_of_reviews  number_of_reviews_l30d  reviews_per_month  \
# 0                225                       1               1.22
#
#    reviews_per_month  review_scores_rating  review_scores_value  \
# 0               1.22                  4.86                 4.73
#
#   instant_bookable  calculated_host_listings_count  \
# 0                f                              14
#
#    calculated_host_listings_count  price    price
# 0                              14  140.0  $140.00

# %%
def data_cleanup(df, new_columns):
    df_regression_master = df[new_columns]
    df_regression_master = df_regression_master.loc[:, ~df_regression_master.columns.duplicated()]
    
    categorical= list(df_regression_master.dtypes[df_regression_master.dtypes=='object'].index)
    numerical = list(df_regression_master.dtypes[df_regression_master.dtypes!='object'].index)
    
    for c in categorical:
        df_regression_master = df_regression_master[df_regression_master[c].notna()]
        
    for c in numerical:
        df_regression_master.loc[:,c] = df_regression_master.loc[:,c].fillna(0)
    
    return df_regression_master

# %%
df_merged_listings = pd.concat([df_listings, df_listings_details], axis=1)

# %%
df_regression_master = data_cleanup(df_merged_listings, listings_selected_columns)

# %%
df_regression_master.head(2)
# Out:
#       id                                               name        room_type  \
# 0  40625                     Near Palace Schönbrunn, Apt. 1  Entire home/apt
# 1  51287  little studio- next to citycenter- wifi- nice ...  Entire home/apt
#
#    minimum_nights  availability_eoy  availability_365  \
# 0               1                69               137
# 1              30                46               207
#
#    estimated_occupancy_l365d  estimated_revenue_l365d  number_of_reviews  \
# 0                         48                   6720.0                225
# 1                        180                  12780.0                383
#
#    number_of_reviews_l30d  reviews_per_month  review_scores_rating  \
# 0                       1               1.22                  4.86
# 1                       0               2.15                  4.67
#
#    review_scores_accuracy  review_scores_checkin  review_scores_cleanliness  \
# 0                    4.91                   4.89                       4.89
# 1                    4.78                   4.92                       4.51
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.94                    4.61                 4.73
# 1                         4.95                    4.87                 4.59
#
#   instant_bookable  calculated_host_listings_count  price
# 0                f                              14  140.0
# 1                f                               2   71.0

# %%
df_regression_master.columns = df_regression_master.columns.str.lower()
df_regression_master.columns = df_regression_master.columns.str.replace(' ','_')

# %%
df_regression_master.head(2)
# Out:
#       id                                               name        room_type  \
# 0  40625                     Near Palace Schönbrunn, Apt. 1  Entire home/apt
# 1  51287  little studio- next to citycenter- wifi- nice ...  Entire home/apt
#
#    minimum_nights  availability_eoy  availability_365  \
# 0               1                69               137
# 1              30                46               207
#
#    estimated_occupancy_l365d  estimated_revenue_l365d  number_of_reviews  \
# 0                         48                   6720.0                225
# 1                        180                  12780.0                383
#
#    number_of_reviews_l30d  reviews_per_month  review_scores_rating  \
# 0                       1               1.22                  4.86
# 1                       0               2.15                  4.67
#
#    review_scores_accuracy  review_scores_checkin  review_scores_cleanliness  \
# 0                    4.91                   4.89                       4.89
# 1                    4.78                   4.92                       4.51
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.94                    4.61                 4.73
# 1                         4.95                    4.87                 4.59
#
#   instant_bookable  calculated_host_listings_count  price
# 0                f                              14  140.0
# 1                f                               2   71.0

# %%
interested_features = ['minimum_nights', 'availability_eoy','number_of_reviews', 'number_of_reviews_l30d', 'reviews_per_month', 'review_scores_rating', 'instant_bookable', 'calculated_host_listings_count']
target = 'price'

# %%
X_full = df_regression_master[interested_features]
y_full = df_regression_master[target]

X_train_val, X_test, y_train_val, y_test = train_test_split(X_full, y_full, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)
len(X_train), len(X_val), len(X_test)
# Out:
# (8473, 2825, 2825)

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/32/2sy0mttn5h569fkh9_bgvm680000gn/T/ipykernel_13010/1188698171.py in ?()
# ----> 1 lin_reg.fit(X_train, y_train)
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_base.py in ?(self, X, y, sample_weight)
#     614         n_jobs_ = self.n_jobs
#     615
#     616         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     617
# --> 618         X, y = validate_data(
#     619             self,
#     620             X,
#     621             y,
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2967             if "estimator" not in check_y_params:
#    2968                 check_y_params = {**default_check_params, **check_y_params}
#    2969             y = check_array(y, input_name="y", **check_y_params)
#    2970         else:
# -> 2971             X, y = check_X_y(X, y, **check_params)
#    2972         out = X, y
#    2973
#    2974     if not no_val_X and check_params.get("ensure_2d", True):
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364         )
#    1365
#    1366     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1367
# -> 1368     X = check_array(
#    1369         X,
#    1370         accept_sparse=accept_sparse,
#    1371         accept_large_sparse=accept_large_sparse,
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050                         )
#    1051                     array = xp.astype(array, dtype, copy=False)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#    1056                     "Complex data not supported\n{}\n".format(array)
#    1057                 ) from complex_warning
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     753         # Use NumPy API to support order
#     754         if copy is True:
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#     759         # At this point array is a NumPy ndarray. We convert it to an array
#     760         # container that is consistent with the input's namespace.
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: 't'
